# %% [markdown]
# Plots in 2 and 3 dimensions

# %%
# use future imports for python 3.x forward compatibility
from __future__ import print_function
from __future__ import division
from __future__ import absolute_import

# other imports
import random
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
# %matplotlib notebook

# project imports
import rand
import halton
import bfs

# %%
# 2 dimensional plot

N=1000
seq = rand.rand_seq
#seq = halton.halton_seq
#seq = bfs.bfs_seq

nums = seq(s=2, N=N)
print('number of points = {}'.format(len(nums)))

x = [num[0] for num in nums]
y = [num[1] for num in nums]

# plot the 2 dimensional halton sequence
plt.rcParams['figure.figsize'] = [7, 5]
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.plot(x, y, 'o', color='black');
plt.show()
# Out:
# number of points = 1000
# <img src="data:image/png;base64,..." width="700">

# %%
# 3 dimensional plot

N=1000

nums = seq(s=3, N=N)
print('number of points = {}'.format(len(nums)))

x = [num[0] for num in nums]
y = [num[1] for num in nums]
z = [num[2] for num in nums]

plt.rcParams['figure.figsize'] = [7, 7]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, c='r', marker='o')

ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')

plt.show()
# Out:
# number of points = 1000
# <img src="data:image/png;base64,..." width="700">
