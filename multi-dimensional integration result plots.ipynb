# %%
# use future imports for python 3.x forward compatibility
from __future__ import print_function
from __future__ import division
from __future__ import absolute_import

# other imports
import random
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
# %matplotlib notebook

# project imports
import rand
import halton
import bfs

# %%
r = [1.46e-02, 4.31e-02, 4.95e-02, 1.41e-02, 8.28e-03,
     9.57e-03, 4.56e-03, 1.56e-02, 3.72e-02, 1.13e-02,
     3.86e-02, 1.58e-02, 3.34e-03, 7.54e-03, 8.23e-03]

x = [i for i in range(1, len(r)+1)]

plt.figure(figsize=(7,5))
plt.scatter(x, r)
plt.plot(x, r, label='random')

h = [3.77e-04, 6.75e-04, 3.55e-04, 3.74e-04, 2.95e-04,
     5.49e-04, 3.59e-04, 2.80e-03, 9.76e-05, 4.02e-04,
     1.34e-03, 6.15e-04, 7.12e-04, 1.26e-03, 2.42e-04]

plt.scatter(x, h)
plt.plot(x, h, label='rand-shift Halton')

b = [2.35e-06, 8.03e-05, 2.60e-03, 3.81e-03, 1.49e-03,
     1.01e-03, 4.90e-03, 8.86e-03, 1.25e-02, 7.36e-03,
     2.14e-02, 4.10e-04, 1.13e-02, 1.04e-02, 1.55e-02]

plt.scatter(x, b)
plt.plot(x, b, label='BFS')

plt.title("N=10,000; m=40", fontsize=19)
plt.xlabel("Dimensions (s)")
plt.ylabel("Pct error")
plt.legend(loc='best')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
r = [1.71e-03, 2.79e-03, 7.51e-04, 1.02e-03, 1.65e-02,
     1.68e-03, 3.11e-04, 4.32e-03, 3.16e-03, 1.96e-03,
     8.61e-03, 1.10e-03, 9.83e-04, 5.01e-03, 7.99e-03]
x = [i for i in range(1, len(r)+1)]

plt.figure(figsize=(7,5))
plt.scatter(x, r)
plt.plot(x, r, label='random')

h = [7.29e-06, 4.13e-05, 5.71e-05, 1.18e-04, 7.98e-05,
     1.04e-04, 2.68e-05, 9.72e-05, 2.71e-05, 7.15e-05,
     4.24e-05, 1.10e-04, 3.10e-04, 3.09e-04, 5.27e-05]

plt.scatter(x, h)
plt.plot(x, h, label='rand-shift Halton')

b = [2.71e-08, 7.65e-05, 1.92e-04, 7.97e-04, 5.06e-04,
     2.56e-03, 9.34e-04, 1.19e-03, 3.63e-04, 7.40e-04,
     2.13e-04, 4.55e-04, 1.62e-03, 1.31e-03, 4.61e-03]

plt.scatter(x, b)
plt.plot(x, b, label='BFS')

plt.title("N=100,000; m=40", fontsize=19)
plt.xlabel("Dimensions (s)")
plt.ylabel("Pct error")
plt.legend(loc='best')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
# fn_cd, n=1,000 (pct error, std)
r = 1.27e-01, 9.00e-03
h = 7.88e-02, 2.48e-03
b = 2.44e-01, 4.53e-03

# fn_cd, n=10,000
r = 1.71e-02, 2.35e-03
h = 1.21e-02, 3.73e-04
b = 4.74e-02, 8.21e-04

# fn_cd, n=100,000
r = 1.21e-02, 6.92e-04
h = 2.86e-03, 6.00e-05
b = 9.42e-04, 2.09e-04
